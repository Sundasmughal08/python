# %%
import pandas as pd

# %%
dataframe = {"name": ["ali" , "ahmad" , "ayan"] ,
             "marks": [23,45,34] ,
             "city": ["lhr", "grw" , "isb"]
             }
df = pd.DataFrame(dataframe)
print(df)
print(df["name"])
print(df.iloc[1])
# Out:
#     name  marks city
# 0    ali     23  lhr
# 1  ahmad     45  grw
# 2   ayan     34  isb
# 0      ali
# 1    ahmad
# 2     ayan
# Name: name, dtype: str
# name     ahmad
# marks       45
# city       grw
# Name: 1, dtype: object
